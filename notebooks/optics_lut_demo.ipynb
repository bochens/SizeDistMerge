# %% [markdown]
# # Optical LUT Demo
#
# A small example showing packaged POPS/UHSAS lookup-table access.

# %%
import sizedistmerge as sdm

uhsas_lut = sdm.lut_path("uhsas")
pops_lut = sdm.lut_path("pops")

print("UHSAS LUT:", uhsas_lut)
print("POPS LUT:", pops_lut)
print("UHSAS exists:", uhsas_lut.exists())
print("POPS exists:", pops_lut.exists())

# %%
lut = sdm.SigmaLUT(str(uhsas_lut))
print(type(lut).__name__)
